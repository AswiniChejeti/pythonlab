# %%
# right angle triangle
num=5
for i in range(num):
    print("* "*(i+1))
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *

# %%
num=5
for i in range(num):
    print(" "*(num-i-1)+"*"*(i+1))
# Out:
#     *
#    **
#   ***
#  ****
# *****

# %%
num=5
for i in range(num):
    print("* "*(num-i))
# Out:
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
num=5
for i in range(num):
    print(" "*i+"*"*(num-i))
# Out:
# *****
#  ****
#   ***
#    **
#     *

# %%
num=5
for i in range(num):
    if i%2==0:
        print(" "*(i)+"* "*(num-i))
# Out:
# * * * * *
#   * * *
#     *

# %%
num=7
for i in range(num):
    if i<=(num//2):
        print(" "*((num//2)-i)+"* "*(i+1))
    else:
        print(" "*(i-num//2)+"* "*(num-i))
# Out:
#    *
#   * *
#  * * *
# * * * *
#  * * *
#   * *
#    *

# %%
num = 7
for i in range(num):
    if i <= num // 2:
        print(" " * ((num // 2) - i) + "*" * (2*i + 1))
    else:
        print(" " * (i - num // 2) + "*" * (2*(num - i) - 1))
# Out:
#    *
#   ***
#  *****
# *******
#  *****
#   ***
#    *
