# %%
'''Write a program to create a tuple and display its elements.

Write a program to find the largest and smallest element in a tuple.

Write a program to convert a list into a tuple and vice versa.

Write a program to count the occurrences of an element in a tuple.

Write a program to concatenate two tuples.

Write a program to slice a tuple and print the result.

Write a program to check whether an element exists in a tuple.

Write a program to find the index of an element in a tuple.

Write a program to sort a tuple of numbers.

Write a program to create a nested tuple and access its elements.'''

# %%
t=(9,8,7,6,5,4,43,2)
print(type(t),t)
# Out:
# <class 'tuple'> (9, 8, 7, 6, 5, 4, 43, 2)

# %%
t1=(9,8,7,6,5,4,3,23)
_max=max(t1)
_min=min(t1)
print(_min)
print(_max)
# Out:
# 3
# 23

# %%
t2=(9,8,7,6,5,4)
t3=list(t2)
print(t3)


t4=[6,8,9,7]
print(tuple(t4))
# Out:
# [9, 8, 7, 6, 5, 4]
# (6, 8, 9, 7)

# %%
t5=(2,3,1,2,3,2,3,4)
n=2
count=0
for n in t5:
    count+=1
print(count)
# Out:
# 8
