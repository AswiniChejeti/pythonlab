# %%
#1, Reverse a string by using slicing
data="Hello World!"
print(data[::-1])
# Out:
# !dlroW olleH

# %%
# 2, reverse a string by using reversed function

data="Good Morning!" 
data1=reversed(data)
output=''.join(data1)
print(output)
# Out:
# !gninroM dooG

# %%
#3, reverse a string by using  while loop
data="Have a nice day"
i=len(data)-1
output=""
while i>=0:
    output+=data[i]
    i-=1
print(output)
# Out:
# yad ecin a evaH

# %%
#4, write a program to reverse order of words in given string

data="python is high level general purpose programing language"
data1=data.split()
output=' '.join(data1[::-1])
print(output)
# Out:
# language programing purpose general level high is python

# %%
#5 write a program to reverse of internal content of each word

data="python programing language is easy to learn bcz easy syntax"
data1=data.split()
output=[]
for word in data1:
    output.append(word[::-1])
print(' '.join(output))
# Out:
# nohtyp gnimargorp egaugnal si ysae ot nrael zcb ysae xatnys

# %%
#6, write a program to reverse internal content of every second word in string
data="python is an interpreted programming language"
data1=data.split()
i=0
output=[]
while i<len(data1):
    if i%2==0:
        output.append(data1[i][::-1])
    else:
        output.append(data1[i])
    i+=1
print(' '.join(output))
# Out:
# nohtyp is na interpreted gnimmargorp language

# %%
#7, write a program to the character present at even index and odd index seperatly for the given string
data="python"
odd=""
even=""
for i,ch in enumerate(data):
    if i%2==0:
        even+=ch
    else:
        odd+=ch
print("even index characters :",even)
print("odd index charctera :",odd)
# Out:
# even index characters : pto
# odd index charctera : yhn

# %%
#7, write a program to the character present at even index and odd index seperatly for the given string

data="python"
print("even index characters :",data[::2])
print("odd index characters  :",data[1::2])
# Out:
# even index characters : pto
# odd index characters  : yhn

# %%
#8,write a program to merge two string alternatively
word1="python"
word2="java"
i,j=0,0
output=""
while i<len(word1) or j<len(word2):
    if i<len(word1):
        output+=word1[i]
        i+=1
    if j<len(word2):
        output+=word2[j]
        j+=1    
print(output)
# Out:
# pjyatvhaon

# %%
#9,program to sort caracters of the string  first alphabet symbols follwed by digits
data="py1th2on3"
alpha=[]
digit=[]
for ch in data:
    if ch.isalpha():
        alpha.append(ch)
    elif ch.isdigit():
        digit.append(ch)
print(''.join(sorted(alpha)+sorted(digit)))
# Out:
# hnopty123

# %%
#9,program to sort caracters of the string  first alphabet symbols follwed by digits
data="py14tho39n5"
alpha=""
digit=""
for ch in data:
    if ch.isalpha():
        alpha+=ch
    if ch.isdigit():
        digit+=ch
print(''.join(sorted(alpha)+sorted(digit)))
# Out:
# hnopty13459

# %%
#10, even index char as capital and odd index char as small
data="GeN AI University"
result=""
index=0
for ch in data:
    if ch==" ":
        result+=" "
    else:
        if index%2==0:
            result+=ch.upper()
        else:
            result+=ch.lower()
    index+=1
print(result)
# Out:
# GeN Ai uNiVeRsItY

# %%
#11, program for the requirement
#input:a4b3c2 expected output:aaaabbbcc

data="a4b3ec2"
output=""
for i,ch in enumerate(data):
    if ch.isalpha() and data[i+1].isdigit():
        output+=ch*int(data[i+1])
    elif ch.isalpha():
        output+=ch
print(output)
# Out:
# aaaabbbecc

# %%
#11, program for the requirement
#input:a4b3c2 expected output:aaaabbbcc
data="a4b3ec2"
output=""
for ch in data:
    if ch.isalpha():
        char=ch
    else:
        digi=int(ch)
        output+=char*digi
print(output)
# Out:
# aaaabbbcc

# %%
#longest sub sequent

s="abcfghxyz"
output=[]

res=""
max1=""

for i in range(0,len(s)-1):
    if ord(s[i])==ord(s[i+1])-1 :
        res+=s[i]
    else:
        if len(res)>len(max1):
            max1=res
    res=s[i]
if len(res) > len(max1):
    max1 = res


print(max1)
# Out:
# b

# %%
s = "abcfghxyz"

res = s[0]
max1 = s[0]

for i in range(len(s) - 1):
    if ord(s[i+1]) == ord(s[i]) + 1:
        res += s[i+1]
    else:
        if len(res) > len(max1):
            max1 = res
        res = s[i+1]


if len(res) > len(max1):
    max1 = res

print(max1)
# Out:
# abc

# %%
data="abceaxyzbij"
output=""
i=len(data)-1
while i>=0:
    if data[i] not in output:
        output+=data[i]
    i-=1
print(output[::-1])
# Out:
# ceaxyzbij

# %%
data="abceaxyzbij"
l = []
s = set()
for i in range(len(data)-1, -1 , -1):
    if data[i] not in s:
        s.add(data[i])
        l.append(data[i])
print(''.join(l[::-1]))
# Out:
# ceaxyzbij
