# %%
#find whether given string is palindrome
s="madam"
result=""
i=len(s)-1
while i>=0:
    result+=s[i]
    i-=1
if s==result:
    print("palindrome")
else:
    print("not palindrome")
# Out:
# palindrome

# %%
#using two pointer 
# from the above traditional appraoch we facing 1,reverse=O(n) and 2,compare O(n)
