# %%
trans1 = {
    1237: [87522, 35454],
    1234: [1000, 8908778],
    1999: [34657, 645578, 98765]
}

print (trans1.get(1111, []))
print(trans1)
  # returns [] if key not found
# Out:
# []
# {1237: [87522, 35454], 1234: [1000, 8908778], 1999: [34657, 645578, 98765]}

# %%
#setdefault()
print(trans1.setdefault(1111,[]))
print(trans1)
# Out:
# []
# {1237: [87522, 35454], 1234: [1000, 8908778], 1999: [34657, 645578, 98765], 1111: []}

# %%
#defaultdict()
from collections import defaultdict
trans1=defaultdict(int)
print(trans1[45788])

trans1=defaultdict(list)
trans1[1235].append(560000)
print(trans1.items())
# Out:
# 0
# dict_items([(1235, [560000])])

# %%
#exercise program: prepare contact list for given cdr
cdr=[(98754365,987523536),
     (807236781,97588345),
     (98754365,987523536),
     (807236781,97588345),
     (98754365,987523536),
     (807236781,97588345),
     (909435782,37502968),
     (97588345,807236781),
     (98754365,981469578),
     (98754365,8906318956)
     ]
from collections import defaultdict
call_list=defaultdict(set)
for callee,caller in cdr:
    call_list[callee].add(caller)
print(call_list)
# Out:
# defaultdict(<class 'set'>, {98754365: {987523536, 981469578, 8906318956}, 807236781: {97588345}, 909435782: {37502968}, 97588345: {807236781}})
