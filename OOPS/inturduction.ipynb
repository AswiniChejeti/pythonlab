# %%
x=20
print(type(x))
# Out:
# <class 'int'>

# %%
"""python is object oriented programming language. It is a programming paradigm that uses objects and classes to organize code and data. In python, everything is an object, including functions, modules, and even classes themselves. This allows for a more flexible and modular approach to programming, as well as the ability to create reusable code.
   
   each and every thing is object and class

"""

# %%
#custom variables

class Employee:
    def __init__(self):
        self.eid=123
        self.name="raj"
        self.salary=45000
        self.dept="chemistry"

#object creation
e=Employee()

#object printing
print(e.eid,e.name)

#we can create multiple objects by using single class
e2=Employee()
e3=Employee()
#here all the variables having same data
# Out:
# 123 raj

# %%
#instance of class is called bject
class Emp:
    def __init__(self,_eid,_ename,_esal):
        #temp varibles(_eid,_ename,_esal)
        self.eid=_eid
        self.name=_ename
        self.sal=_esal

#object creation
e1=Emp(1,"raj",450000)
e2=Emp(2,"RAHUL",340000)

print(e2.eid)
# here all the objects having different data
# Out:
# 2

# %%
#__init__:  :    is a constructor ,which is used to initilize instance variables/attributes
#class purpose is to restrict attributes as well to work with that variables with help of methods
#self:  1, self is the first attribute of the every function/method.
#        2,self means my object reference/address
#        3,self is not inbuilt attribute ,it is just identifers of attribute we can also use our chioce it will work
#        4,but in traditional way of coding from past years we using self as attribute

# %%
class Car:
    brand="BMW"#Static variables: common for all objects
    def __init__(self,model,color):
        self.model=model
        self.color=color

    def info(self):
        return (self.model,self.color,Car.brand)
car1=Car("neo","blue")
print(car1.info())
print(car1.__dict__)
Car.__dict__
# Out:
# ('neo', 'blue', 'BMW')
# {'model': 'neo', 'color': 'blue'}
# mappingproxy({'__module__': '__main__',
#               'brand': 'BMW',
#               '__init__': <function __main__.Car.__init__(self, model, color)>,
#               'info': <function __main__.Car.info(self)>,
#               '__dict__': <attribute '__dict__' of 'Car' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Car' objects>,
#               '__doc__': None})

# %%
#first principal is data binding: binding data with class and object
# binding the attributes with relevent methods

#when to we write a class
# Class can be defined to model any entity ,process or an idea

from datetime import datetime

class Book:
    count=None
    def __initr__(self):
        self.isbn=None
        self.title=None
        self.pages=None
        self.authors=[]
        Book.count+=1

class Student:
    count=None
    def __init__(self,rno,sname,sbranch,syear):
        self.rollno=rno
        self.name=sname
        self.branch=sbranch
        self.year=syear
        Student.count+=1

class LibraryManagement:
    def __init__(self):
        self.books={}
        self.students={}
        self.entry_book=[]

    def entry(self,book,student,operation="issue"):
        self.entry_book.append(book,student,operation,datetime.now())

    def add_book(self,book):
        self.books[book.isbn]=book

    def add_student(self,student):
        pass
