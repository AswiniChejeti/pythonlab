# %%
# string element into int elements
list1=['2','3.5','11.98','6']
list2=[]
for i in list1:
    list2.append(round(float(i)))
print(list2)
# Out:
# [2, 4, 12, 6]

# %%
n1 = int(input("enter a number  : "))
n2 = n1 + 1
l2 = [n1, n2]
for roon in l2:
    factor= []
    total=0
    for i in range(1, roon+1):
        if roon % i == 0:
            factor.append(i)

    print(f"Divisors of {roon}: {factor}")

    prime_divisors = []
    for j in factor:
        if j > 1: 
            for k in range(2, int(j**0.5) + 1):
                if j % k == 0:
                    break
            else:  # runs only if loop didn't break → j is prime
                prime_divisors.append(j)
                total += j
                print(j)
        
    print(f"Running total: {total}")

# %%
print("hii")

# %%
e = [(1, 'Nick $$#  Jr.', 23, '45000.0$'), 
     (2, 'Nick Jr.', 63, '245000.0&**&'),
     (3, 'Nick Sr.', 53, 145000.0),
     (4, 'Dan  ^^', 23, '45000.0'),
     (5, 'Steve',23,46000.0)]
unw=''.join([chr(i) for i in range(32,32 +15)] + \
            [chr(i) for i in range(32+26, 32+26+7)] + ['^'])
cleaned_employees = []
for emp in e:
    _id, name, age, sal = emp
    new_name = ''.join([ch for ch in name if ch not in unw])
    new_name = new_name.replace('Jr', ' jr').replace('Sr', ' sr')
    new_sal =float(str(sal).strip(unw))
    cleaned_employees.append((_id, new_name, age, new_sal))

    updated = []
    salary_lakhs = new_sal / 100000
    if salary_lakhs <= 5:
        updated_sal = new_sal * 0.05
    elif salary_lakhs <= 10:
        updated_sal = new_sal * 0.10
    else:
        updated_sal = new_sal * 0.15
    updated.append((_id, new_name, age, round(new_sal - updated_sal,2)))
    print(f'Updated salaries after bonus deduction:{updated}')
_max=max(cleaned_employees, key=lambda x: x[-1])[-1]
_min=min(cleaned_employees, key=lambda x:x[-1])[-1]

print(f'Desending order:{sorted(cleaned_employees, key=lambda x: x[3], reverse=True)}')
print(f'Acending order:{sorted(cleaned_employees, key=lambda x: x[3])}')

for i in cleaned_employees:
    if _max==i[-1]:
        print(f'employees with heighest salaries:{i[1]}')
    if _min==i[-1]:
        print(f'employees with least salaries:{i[1]}')

   # print(f'Updated salaries after bonus deduction:{updated}')

# %%
l=[]
tuple1=(21,'raju',23000.0,25)
tuple2=(22,'rani',45000.0,45)
tuple3=(23,'rose',55000.0,42)
l.append(tuple1)
l.append(tuple2)
l.append(tuple3)
print(l)
# Out:
# [(21, 'raju', 23000.0, 25), (22, 'rani', 45000.0, 45), (23, 'rose', 55000.0, 42)]

# %%
n=int(input("enter how many records you want : "))
list1=[]
list2=[]
tuple1=()
for i in range(n):
    id=int(input("enter employee id: "))
    name=str(input("enter employee name : "))
    sal=float(input(" enter sal :"))
    age=int(input("enter age :"))
    
    
    list2.append(tuple([id,name,sal,age]))
print(list2)
# Out:
# [(1, 'a', 3400.0, 23), (2, 'b', 23000.0, 23), (3, 'c', 34000.0, 24), (4, 'd', 340000.0, 34)]

# %%
n=int(input())
loe=[]
for i in range(n):
    id,name,age,sal=input().split(',')
    loe.append([id,name,age,sal])
loe_ = [(int(i[0]),i[1],int(i[2]),float(i[3])) for i in loe]
print(loe_)

# %%
emp_rec=[(1, 'Nick', 23, 45000.0),

    (2, 'Nick Jr.', 63, 245000.0),

    (3, 'Nick Sr.', 53, 145000.0),

    (4, 'Dan', 23, 45000.0),

    (5, 'Steve', 23, 46000.0)]
sorted(emp_rec,key=lambda x:x[3])
sorted(emp_rec,key=lambda x:x[3], reverse=True)
max(emp_rec,key=lambda x:x[3])[1]
min(emp_rec,key=lambda x:x[3])[1]
# Out:
# 'Nick'

# %%
emp_rec=[(1, 'Nick', 23, 45000.0),

    (2, 'Nick Jr.', 63, 245000.0),

    (3, 'Nick Sr.', 53, 45000.0),

    (4, 'Dan', 23, 45000.0),

    (5, 'Steve', 23, 46000.0)]
sorted(emp_rec,key=lambda x:x[-1])
_min=min(emp_rec,key=lambda x:x[-1])[-1]
for i in emp_rec:
    if i[-1]==_min:
        print(i[1])
# Out:
# Nick
# Nick Sr.
# Dan

# %%
emp_rec=[(1, 'Nick', 23, 45000.0),

    (2, 'Nick Jr.', 63, 245000.0),

    (3, 'Nick Sr.', 53, 245000.0),

    (4, 'Dan', 23, 45000.0),

    (5, 'Steve', 23, 46000.0)]
sorted(emp_rec,key=lambda x:x[-1])
_max=max(emp_rec,key=lambda x:x[-1])[-1]
for i in emp_rec:
    if i[-1]==_max:
        print(i[1])
# Out:
# Nick Jr.
# Nick Sr.
