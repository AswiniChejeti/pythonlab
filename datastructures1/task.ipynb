# %%
from datetime import datetime
shipping=[
  {
    "order_id": "ORD1001",
    "customer_name": "Harold Gomez",
    "region": "Middle East",
    "shipping_address": "8736 Jackie Skyway Suite 670, South Carlosville, CT 70713",
    "weight_kg": 0.6,
    "shipping_cost_usd": 19.51,
    "status": "In Transit",
    "order_date": "2025-10-14",
    "delivery_date": "2025-10-26"
  },
  {
    "order_id": "ORD1002",
    "customer_name": "Jared Mcdonald",
    "region": "Australia",
    "shipping_address": "15849 Howell Gardens Apt. 070, Jaimestad, NE 95322",
    "weight_kg": 2.16,
    "shipping_cost_usd": 23.03,
    "status": "Pending",
    "order_date": "2025-10-01",
    "delivery_date": "2025-10-22"
  },
  {
    "order_id": "ORD1003",
    "customer_name": "Olivia Mayer",
    "region": "Europe",
    "shipping_address": "621 Mills Place, Port Nicole, OK 01913",
    "weight_kg": 1.97,
    "shipping_cost_usd": 23.34,
    "status": "Pending",
    "order_date": "2025-10-07",
    "delivery_date": "2025-10-29"
  },
  {
    "order_id": "ORD1004",
    "customer_name": "Cynthia Thompson",
    "region": "Europe",
    "shipping_address": "95048 Samantha Points Apt. 499, North Christopherview, UT 31667",
    "weight_kg": 2.81,
    "shipping_cost_usd": 17.66,
    "status": "Pending",
    "order_date": "2025-09-29",
    "delivery_date": "2025-11-02"
  },
  {
    "order_id": "ORD1005",
    "customer_name": "Stephen Romero",
    "region": "Australia",
    "shipping_address": "56167 Christopher Spur Apt. 556, Waynefurt, VT 88023",
    "weight_kg": 4.28,
    "shipping_cost_usd": 13.5,
    "status": "In Transit",
    "order_date": "2025-10-21",
    "delivery_date": "2025-10-25"
  },
  {
    "order_id": "ORD1006",
    "customer_name": "Maria Dunn",
    "region": "North America",
    "shipping_address": "086 Wright Orchard, East Heathertown, LA 41014",
    "weight_kg": 3.43,
    "shipping_cost_usd": 14.22,
    "status": "Pending",
    "order_date": "2025-10-06",
    "delivery_date": "2025-10-24"
  },
  {
    "order_id": "ORD1007",
    "customer_name": "Michelle Liu",
    "region": "South America",
    "shipping_address": "USNV Vargas, FPO AP 22128",
    "weight_kg": 1.87,
    "shipping_cost_usd": 12.35,
    "status": "Delivered",
    "order_date": "2025-09-30",
    "delivery_date": "2025-10-29"
  },
  {
    "order_id": "ORD1008",
    "customer_name": "Sean Schaefer",
    "region": "Asia",
    "shipping_address": "4535 Alexandra Grove Suite 882, South Jessicaton, NV 00938",
    "weight_kg": 0.56,
    "shipping_cost_usd": 11.65,
    "status": "Pending",
    "order_date": "2025-09-25",
    "delivery_date": "2025-11-03"
  },
  {
    "order_id": "ORD1009",
    "customer_name": "Bruce Lopez",
    "region": "North America",
    "shipping_address": "Unit 2849 Box 5306, DPO AE 30727",
    "weight_kg": 2.91,
    "shipping_cost_usd": 24.28,
    "status": "Pending",
    "order_date": "2025-10-08",
    "delivery_date": "2025-11-04"
  },
  {
    "order_id": "ORD1010",
    "customer_name": "Bradley Medina",
    "region": "Middle East",
    "shipping_address": "51161 Wendy Springs, South Jasmineshire, VA 89487",
    "weight_kg": 4.66,
    "shipping_cost_usd": 19.53,
    "status": "Delivered",
    "order_date": "2025-10-13",
    "delivery_date": "2025-10-22"
  },
  {
    "order_id": "ORD1011",
    "customer_name": "Jeffrey Greene",
    "region": "Middle East",
    "shipping_address": "920 Tucker Heights Apt. 214, Grayhaven, GA 68691",
    "weight_kg": 2.46,
    "shipping_cost_usd": 16.76,
    "status": "Pending",
    "order_date": "2025-10-11",
    "delivery_date": "2025-10-30"
  },
  {
    "order_id": "ORD1012",
    "customer_name": "Katherine Brewer",
    "region": "Europe",
    "shipping_address": "1968 Henderson Plain Suite 411, Stephenside, SD 52093",
    "weight_kg": 4.4,
    "shipping_cost_usd": 22.49,
    "status": "Delivered",
    "order_date": "2025-10-02",
    "delivery_date": "2025-10-28"
  },
  {
    "order_id": "ORD1013",
    "customer_name": "Nicholas Hansen",
    "region": "South America",
    "shipping_address": "19171 Herrera Pike Apt. 829, Barreraport, LA 13918",
    "weight_kg": 3.3,
    "shipping_cost_usd": 22.72,
    "status": "In Transit",
    "order_date": "2025-10-01",
    "delivery_date": "2025-10-30"
  },
  {
    "order_id": "ORD1014",
    "customer_name": "Angela Thompson",
    "region": "Middle East",
    "shipping_address": "515 Jones Spur, Joneschester, AK 27812",
    "weight_kg": 3.3,
    "shipping_cost_usd": 15.6,
    "status": "In Transit",
    "order_date": "2025-10-13",
    "delivery_date": "2025-10-28"
  },
  {
    "order_id": "ORD1015",
    "customer_name": "Jenna Garcia",
    "region": "Europe",
    "shipping_address": "20104 Victoria Trail Apt. 567, Stevenstad, IN 13533",
    "weight_kg": 3.78,
    "shipping_cost_usd": 22.24,
    "status": "Delivered",
    "order_date": "2025-09-30",
    "delivery_date": "2025-10-27"
  },
  {
    "order_id": "ORD1016",
    "customer_name": "Daniel Moore",
    "region": "Europe",
    "shipping_address": "76527 Katelyn Turnpike Suite 394, Wolfefurt, NJ 52058",
    "weight_kg": 1.23,
    "shipping_cost_usd": 12.02,
    "status": "Delivered",
    "order_date": "2025-10-01",
    "delivery_date": "2025-11-02"
  },
  {
    "order_id": "ORD1017",
    "customer_name": "Bridget Brown",
    "region": "Australia",
    "shipping_address": "78100 Michael Camp Apt. 122, Deborahburgh, KY 79956",
    "weight_kg": 2.62,
    "shipping_cost_usd": 6.41,
    "status": "Pending",
    "order_date": "2025-10-15",
    "delivery_date": "2025-10-25"
  },
  {
    "order_id": "ORD1018",
    "customer_name": "Brooke Brooks",
    "region": "South America",
    "shipping_address": "110 Carson Track Apt. 760, Barrettview, IN 36556",
    "weight_kg": 1.64,
    "shipping_cost_usd": 7.97,
    "status": "In Transit",
    "order_date": "2025-10-14",
    "delivery_date": "2025-10-26"
  },
  {
    "order_id": "ORD1019",
    "customer_name": "Timothy Goodman",
    "region": "South America",
    "shipping_address": "01096 William Springs, West Lauren, NV 15250",
    "weight_kg": 2.07,
    "shipping_cost_usd": 19.01,
    "status": "Pending",
    "order_date": "2025-10-16",
    "delivery_date": "2025-10-28"
  },
  {
    "order_id": "ORD1020",
    "customer_name": "Sean Schneider",
    "region": "Europe",
    "shipping_address": "6109 Alexander Spurs, West Daniel, ND 89997",
    "weight_kg": 0.6,
    "shipping_cost_usd": 18.13,
    "status": "Pending",
    "order_date": "2025-09-26",
    "delivery_date": "2025-10-28"
  },
  {
    "order_id": "ORD1021",
    "customer_name": "Debbie Escobar MD",
    "region": "South America",
    "shipping_address": "6910 Allison Spurs Suite 514, New Annstad, MA 95906",
    "weight_kg": 3.71,
    "shipping_cost_usd": 6.9,
    "status": "Pending",
    "order_date": "2025-10-11",
    "delivery_date": "2025-11-04"
  },
  {
    "order_id": "ORD1022",
    "customer_name": "William Oliver",
    "region": "Asia",
    "shipping_address": "77300 Phillips Wells, Ellishaven, HI 86884",
    "weight_kg": 1.22,
    "shipping_cost_usd": 5.04,
    "status": "In Transit",
    "order_date": "2025-10-14",
    "delivery_date": "2025-10-29"
  },
  {
    "order_id": "ORD1023",
    "customer_name": "David Campbell",
    "region": "Europe",
    "shipping_address": "021 Todd Avenue, Ryanport, IA 48007",
    "weight_kg": 3.72,
    "shipping_cost_usd": 9.84,
    "status": "In Transit",
    "order_date": "2025-10-03",
    "delivery_date": "2025-10-25"
  },
  {
    "order_id": "ORD1024",
    "customer_name": "Stephen Baker",
    "region": "Middle East",
    "shipping_address": "7386 Steven Rest, Lake Kathleen, KS 37390",
    "weight_kg": 1.31,
    "shipping_cost_usd": 7.74,
    "status": "Pending",
    "order_date": "2025-10-14",
    "delivery_date": "2025-10-22"
  },
  {
    "order_id": "ORD1025",
    "customer_name": "Angela Daniels",
    "region": "North America",
    "shipping_address": "04120 David Extensions Suite 083, Maddoxville, LA 04422",
    "weight_kg": 4.47,
    "shipping_cost_usd": 10.92,
    "status": "Pending",
    "order_date": "2025-10-16",
    "delivery_date": "2025-10-24"
  },
  {
    "order_id": "ORD1026",
    "customer_name": "George Jackson",
    "region": "South America",
    "shipping_address": "88081 Natalie Cliff, New Stephenside, SC 10222",
    "weight_kg": 4.56,
    "shipping_cost_usd": 24.19,
    "status": "Delivered",
    "order_date": "2025-10-20",
    "delivery_date": "2025-10-29"
  },
  {
    "order_id": "ORD1027",
    "customer_name": "Jay Lin",
    "region": "Europe",
    "shipping_address": "916 Kenneth Cliffs, Webermouth, RI 65353",
    "weight_kg": 2.64,
    "shipping_cost_usd": 23.4,
    "status": "In Transit",
    "order_date": "2025-10-14",
    "delivery_date": "2025-10-28"
  },
  {
    "order_id": "ORD1028",
    "customer_name": "Elizabeth Henderson",
    "region": "South America",
    "shipping_address": "336 Brenda Plains Suite 124, Lake Timothyberg, SC 24477",
    "weight_kg": 4.68,
    "shipping_cost_usd": 20.37,
    "status": "Delivered",
    "order_date": "2025-10-18",
    "delivery_date": "2025-11-04"
  },
  {
    "order_id": "ORD1029",
    "customer_name": "David Clark",
    "region": "North America",
    "shipping_address": "69986 Bailey Route, Banksland, ME 39872",
    "weight_kg": 2.08,
    "shipping_cost_usd": 22.97,
    "status": "Delivered",
    "order_date": "2025-10-15",
    "delivery_date": "2025-10-27"
  },
  {
    "order_id": "ORD1030",
    "customer_name": "Christopher Johnson",
    "region": "Asia",
    "shipping_address": "634 Kevin Brooks, South Victor, MA 93992",
    "weight_kg": 2.97,
    "shipping_cost_usd": 9.99,
    "status": "In Transit",
    "order_date": "2025-10-02",
    "delivery_date": "2025-10-31"
  },
  {
    "order_id": "ORD1031",
    "customer_name": "Henry Walker",
    "region": "Asia",
    "shipping_address": "3526 Timothy Unions Apt. 250, Angelaland, MA 49823",
    "weight_kg": 3.62,
    "shipping_cost_usd": 20.13,
    "status": "Pending",
    "order_date": "2025-10-09",
    "delivery_date": "2025-11-04"
  },
  {
    "order_id": "ORD1032",
    "customer_name": "James Williams",
    "region": "South America",
    "shipping_address": "2306 Natalie Creek, Amyfort, OH 58494",
    "weight_kg": 2.44,
    "shipping_cost_usd": 6.21,
    "status": "Delivered",
    "order_date": "2025-09-30",
    "delivery_date": "2025-11-03"
  },
  {
    "order_id": "ORD1033",
    "customer_name": "Rebecca Johnson",
    "region": "Middle East",
    "shipping_address": "993 Amanda Knolls Apt. 299, North Jonathan, PA 91726",
    "weight_kg": 1.31,
    "shipping_cost_usd": 22.72,
    "status": "In Transit",
    "order_date": "2025-09-27",
    "delivery_date": "2025-11-02"
  },
  {
    "order_id": "ORD1034",
    "customer_name": "Lisa Carpenter",
    "region": "Asia",
    "shipping_address": "14441 Wallace Groves Suite 601, Jacksonhaven, AK 39435",
    "weight_kg": 1.02,
    "shipping_cost_usd": 7.5,
    "status": "Delivered",
    "order_date": "2025-10-08",
    "delivery_date": "2025-10-24"
  },
  {
    "order_id": "ORD1035",
    "customer_name": "Douglas Thompson",
    "region": "Australia",
    "shipping_address": "178 Robert Divide, Castroland, VA 36539",
    "weight_kg": 4.99,
    "shipping_cost_usd": 7.03,
    "status": "Delivered",
    "order_date": "2025-09-26",
    "delivery_date": "2025-11-02"
  },
  {
    "order_id": "ORD1036",
    "customer_name": "Jo Singh",
    "region": "Australia",
    "shipping_address": "561 Michael Stravenue, Marystad, DE 13155",
    "weight_kg": 1.02,
    "shipping_cost_usd": 14.16,
    "status": "Delivered",
    "order_date": "2025-10-16",
    "delivery_date": "2025-11-01"
  },
  {
    "order_id": "ORD1037",
    "customer_name": "Mr. Darren Harper",
    "region": "Asia",
    "shipping_address": "97429 Berry Extension Apt. 496, Tammyside, OH 17394",
    "weight_kg": 3.04,
    "shipping_cost_usd": 22.9,
    "status": "In Transit",
    "order_date": "2025-10-12",
    "delivery_date": "2025-10-26"
  },
  {
    "order_id": "ORD1038",
    "customer_name": "Tammy Lewis",
    "region": "South America",
    "shipping_address": "468 Moore Burgs, Tinaside, NY 83324",
    "weight_kg": 2.01,
    "shipping_cost_usd": 16.06,
    "status": "Pending",
    "order_date": "2025-09-25",
    "delivery_date": "2025-10-30"
  },
  {
    "order_id": "ORD1039",
    "customer_name": "Christian Reynolds",
    "region": "Asia",
    "shipping_address": "372 Michele Common, South Christina, UT 54498",
    "weight_kg": 4.0,
    "shipping_cost_usd": 18.21,
    "status": "In Transit",
    "order_date": "2025-10-21",
    "delivery_date": "2025-10-29"
  },
  {
    "order_id": "ORD1040",
    "customer_name": "Joseph Porter",
    "region": "Asia",
    "shipping_address": "PSC 1199, Box 3895, APO AP 32779",
    "weight_kg": 1.63,
    "shipping_cost_usd": 6.45,
    "status": "Pending",
    "order_date": "2025-09-22",
    "delivery_date": "2025-11-03"
  },
  {
    "order_id": "ORD1041",
    "customer_name": "Gregory Coleman",
    "region": "Europe",
    "shipping_address": "389 Ryan Plains, Rosalesborough, NC 40643",
    "weight_kg": 1.14,
    "shipping_cost_usd": 9.85,
    "status": "Pending",
    "order_date": "2025-09-28",
    "delivery_date": "2025-10-26"
  },
  {
    "order_id": "ORD1042",
    "customer_name": "Donald White",
    "region": "South America",
    "shipping_address": "9505 Sara Key Suite 743, Stephensonfurt, ME 22243",
    "weight_kg": 2.68,
    "shipping_cost_usd": 18.72,
    "status": "Pending",
    "order_date": "2025-10-11",
    "delivery_date": "2025-10-27"
  },
  {
    "order_id": "ORD1043",
    "customer_name": "Kevin Garcia",
    "region": "Europe",
    "shipping_address": "80317 Johnson Radial Apt. 437, Smithstad, CA 27560",
    "weight_kg": 0.67,
    "shipping_cost_usd": 14.72,
    "status": "Pending",
    "order_date": "2025-10-11",
    "delivery_date": "2025-10-25"
  },
  {
    "order_id": "ORD1044",
    "customer_name": "Alexis Hood",
    "region": "Australia",
    "shipping_address": "14128 Brandon Tunnel Apt. 535, East Michelleview, ND 97900",
    "weight_kg": 3.03,
    "shipping_cost_usd": 21.99,
    "status": "Pending",
    "order_date": "2025-10-18",
    "delivery_date": "2025-10-23"
  },
  {
    "order_id": "ORD1045",
    "customer_name": "Tara Moreno",
    "region": "Middle East",
    "shipping_address": "5093 Zimmerman Drive, South Lauren, WY 32181",
    "weight_kg": 4.47,
    "shipping_cost_usd": 17.99,
    "status": "Delivered",
    "order_date": "2025-09-25",
    "delivery_date": "2025-10-30"
  },
  {
    "order_id": "ORD1046",
    "customer_name": "Mary Austin MD",
    "region": "Asia",
    "shipping_address": "130 Robert Stravenue Suite 129, Port Charlesbury, AR 39778",
    "weight_kg": 1.77,
    "shipping_cost_usd": 8.94,
    "status": "Delivered",
    "order_date": "2025-09-30",
    "delivery_date": "2025-10-30"
  },
  {
    "order_id": "ORD1047",
    "customer_name": "Lisa Lopez",
    "region": "Europe",
    "shipping_address": "851 Thompson Pass, North Katherine, OH 45169",
    "weight_kg": 2.15,
    "shipping_cost_usd": 21.37,
    "status": "Delivered",
    "order_date": "2025-10-01",
    "delivery_date": "2025-11-03"
  },
  {
    "order_id": "ORD1048",
    "customer_name": "Tonya Jones",
    "region": "Middle East",
    "shipping_address": "541 Colleen Meadow, Cantrellshire, NH 54751",
    "weight_kg": 0.85,
    "shipping_cost_usd": 19.72,
    "status": "In Transit",
    "order_date": "2025-10-08",
    "delivery_date": "2025-10-31"
  },
  {
    "order_id": "ORD1049",
    "customer_name": "Jason Brown",
    "region": "South America",
    "shipping_address": "49829 Berry Center, Reynoldsview, CT 29510",
    "weight_kg": 4.22,
    "shipping_cost_usd": 8.46,
    "status": "Delivered",
    "order_date": "2025-10-06",
    "delivery_date": "2025-10-23"
  },
  {
    "order_id": "ORD1050",
    "customer_name": "Christopher Cisneros",
    "region": "North America",
    "shipping_address": "89654 Nguyen Mall Suite 645, Christopherhaven, FL 23330",
    "weight_kg": 0.92,
    "shipping_cost_usd": 17.81,
    "status": "Pending",
    "order_date": "2025-09-24",
    "delivery_date": "2025-10-22"
  },
  {
    "order_id": "ORD1051",
    "customer_name": "Nancy Mccarthy",
    "region": "Middle East",
    "shipping_address": "78123 Rocha Course, Perezhaven, OK 38507",
    "weight_kg": 4.56,
    "shipping_cost_usd": 17.67,
    "status": "Pending",
    "order_date": "2025-10-18",
    "delivery_date": "2025-10-24"
  },
  {
    "order_id": "ORD1052",
    "customer_name": "Mallory Henry",
    "region": "Europe",
    "shipping_address": "Unit 6108 Box 8991, DPO AA 83909",
    "weight_kg": 1.06,
    "shipping_cost_usd": 13.93,
    "status": "In Transit",
    "order_date": "2025-10-16",
    "delivery_date": "2025-10-24"
  },
  {
    "order_id": "ORD1053",
    "customer_name": "Matthew Hurst",
    "region": "Australia",
    "shipping_address": "133 Sara Cape Apt. 909, Kristinfurt, LA 92553",
    "weight_kg": 4.64,
    "shipping_cost_usd": 21.09,
    "status": "Pending",
    "order_date": "2025-10-21",
    "delivery_date": "2025-10-27"
  },
  {
    "order_id": "ORD1054",
    "customer_name": "Holly Shepherd",
    "region": "Australia",
    "shipping_address": "655 Amy Route Apt. 703, Matthewburgh, IN 46712",
    "weight_kg": 3.13,
    "shipping_cost_usd": 11.1,
    "status": "In Transit",
    "order_date": "2025-10-03",
    "delivery_date": "2025-10-28"
  },
  {
    "order_id": "ORD1055",
    "customer_name": "Kimberly Doyle",
    "region": "Europe",
    "shipping_address": "1651 Scott Turnpike, Lake Kristen, TN 07589",
    "weight_kg": 3.72,
    "shipping_cost_usd": 5.56,
    "status": "Pending",
    "order_date": "2025-10-06",
    "delivery_date": "2025-10-27"
  },
  {
    "order_id": "ORD1056",
    "customer_name": "Colin Thompson",
    "region": "Australia",
    "shipping_address": "989 Bennett Forges, Lake Erika, ME 23148",
    "weight_kg": 3.34,
    "shipping_cost_usd": 15.13,
    "status": "In Transit",
    "order_date": "2025-10-10",
    "delivery_date": "2025-11-05"
  },
  {
    "order_id": "ORD1057",
    "customer_name": "Ryan Tyler",
    "region": "North America",
    "shipping_address": "86821 Moses Parkway Apt. 494, Tiffanyfurt, VT 02387",
    "weight_kg": 4.21,
    "shipping_cost_usd": 7.79,
    "status": "Pending",
    "order_date": "2025-10-08",
    "delivery_date": "2025-10-31"
  },
  {
    "order_id": "ORD1058",
    "customer_name": "Teresa Williams",
    "region": "Middle East",
    "shipping_address": "772 Mitchell Club Apt. 340, Cliffordstad, LA 46533",
    "weight_kg": 2.79,
    "shipping_cost_usd": 14.03,
    "status": "In Transit",
    "order_date": "2025-10-03",
    "delivery_date": "2025-11-02"
  },
  {
    "order_id": "ORD1059",
    "customer_name": "Christopher Baker",
    "region": "Middle East",
    "shipping_address": "594 Michael Light Suite 600, North Caseyburgh, AK 04954",
    "weight_kg": 3.86,
    "shipping_cost_usd": 24.61,
    "status": "In Transit",
    "order_date": "2025-10-21",
    "delivery_date": "2025-10-28"
  },
  {
    "order_id": "ORD1060",
    "customer_name": "Christopher Newton",
    "region": "Asia",
    "shipping_address": "9917 Gonzales Fork Suite 677, Port Ashleyport, MA 22397",
    "weight_kg": 4.19,
    "shipping_cost_usd": 22.85,
    "status": "In Transit",
    "order_date": "2025-10-20",
    "delivery_date": "2025-10-27"
  },
  {
    "order_id": "ORD1061",
    "customer_name": "Matthew Proctor",
    "region": "Middle East",
    "shipping_address": "9918 Leah Corners Apt. 542, North Amandaberg, GA 75327",
    "weight_kg": 2.83,
    "shipping_cost_usd": 15.51,
    "status": "Delivered",
    "order_date": "2025-09-25",
    "delivery_date": "2025-11-04"
  },
  {
    "order_id": "ORD1062",
    "customer_name": "Michael Williams",
    "region": "Europe",
    "shipping_address": "05200 Carr Throughway, North Wendy, AR 75310",
    "weight_kg": 2.75,
    "shipping_cost_usd": 15.63,
    "status": "Pending",
    "order_date": "2025-10-03",
    "delivery_date": "2025-10-23"
  },
  {
    "order_id": "ORD1063",
    "customer_name": "Evelyn Oliver",
    "region": "Australia",
    "shipping_address": "4907 Wheeler Rapids, East Brianberg, AZ 40689",
    "weight_kg": 2.06,
    "shipping_cost_usd": 6.9,
    "status": "In Transit",
    "order_date": "2025-10-01",
    "delivery_date": "2025-11-04"
  },
  {
    "order_id": "ORD1064",
    "customer_name": "Beth Orozco",
    "region": "Asia",
    "shipping_address": "49259 Decker Grove Suite 465, Gloriastad, TX 43132",
    "weight_kg": 3.18,
    "shipping_cost_usd": 18.88,
    "status": "Pending",
    "order_date": "2025-10-08",
    "delivery_date": "2025-10-24"
  },
  {
    "order_id": "ORD1065",
    "customer_name": "Steven Salazar",
    "region": "Australia",
    "shipping_address": "152 Thomas Estates Apt. 882, Robersonstad, NE 47698",
    "weight_kg": 3.33,
    "shipping_cost_usd": 6.76,
    "status": "In Transit",
    "order_date": "2025-09-22",
    "delivery_date": "2025-10-26"
  },
  {
    "order_id": "ORD1066",
    "customer_name": "Louis Gomez",
    "region": "North America",
    "shipping_address": "69859 Freeman Motorway Apt. 031, Port Jill, CT 42950",
    "weight_kg": 3.65,
    "shipping_cost_usd": 19.34,
    "status": "In Transit",
    "order_date": "2025-10-06",
    "delivery_date": "2025-10-30"
  },
  {
    "order_id": "ORD1067",
    "customer_name": "Erica Elliott",
    "region": "Europe",
    "shipping_address": "PSC 5487, Box 0499, APO AA 73518",
    "weight_kg": 1.97,
    "shipping_cost_usd": 14.65,
    "status": "Delivered",
    "order_date": "2025-10-18",
    "delivery_date": "2025-10-24"
  },
  {
    "order_id": "ORD1068",
    "customer_name": "Eduardo Beck",
    "region": "Australia",
    "shipping_address": "077 Rebecca Courts Suite 134, Hamiltonchester, VA 38548",
    "weight_kg": 2.06,
    "shipping_cost_usd": 20.26,
    "status": "Delivered",
    "order_date": "2025-10-14",
    "delivery_date": "2025-10-22"
  },
  {
    "order_id": "ORD1069",
    "customer_name": "Mrs. Amber Pena",
    "region": "South America",
    "shipping_address": "40453 Tom Forest, Lake Cameronside, HI 36938",
    "weight_kg": 1.48,
    "shipping_cost_usd": 12.13,
    "status": "In Transit",
    "order_date": "2025-09-26",
    "delivery_date": "2025-11-02"
  },
  {
    "order_id": "ORD1070",
    "customer_name": "Stacey Turner",
    "region": "North America",
    "shipping_address": "59531 Vaughan Pass, Port Johnshire, MD 96122",
    "weight_kg": 0.88,
    "shipping_cost_usd": 5.99,
    "status": "Delivered",
    "order_date": "2025-10-05",
    "delivery_date": "2025-10-22"
  },
  {
    "order_id": "ORD1071",
    "customer_name": "Jessica Wagner",
    "region": "South America",
    "shipping_address": "0598 Dawson Hill Suite 617, Lake Mathewhaven, GA 88307",
    "weight_kg": 4.67,
    "shipping_cost_usd": 16.86,
    "status": "In Transit",
    "order_date": "2025-10-09",
    "delivery_date": "2025-10-29"
  },
  {
    "order_id": "ORD1072",
    "customer_name": "William Nichols",
    "region": "South America",
    "shipping_address": "14980 Kyle Extension Suite 966, Butlerside, NH 53384",
    "weight_kg": 3.72,
    "shipping_cost_usd": 19.67,
    "status": "Delivered",
    "order_date": "2025-10-12",
    "delivery_date": "2025-10-31"
  },
  {
    "order_id": "ORD1073",
    "customer_name": "Kenneth Chambers",
    "region": "Australia",
    "shipping_address": "291 Diana Key, Karenton, CT 64351",
    "weight_kg": 1.08,
    "shipping_cost_usd": 22.2,
    "status": "Delivered",
    "order_date": "2025-10-18",
    "delivery_date": "2025-10-25"
  },
  {
    "order_id": "ORD1074",
    "customer_name": "Thomas Chang",
    "region": "Middle East",
    "shipping_address": "095 Albert Village Apt. 322, Brownmouth, UT 15986",
    "weight_kg": 1.59,
    "shipping_cost_usd": 19.13,
    "status": "Delivered",
    "order_date": "2025-10-09",
    "delivery_date": "2025-11-04"
  },
  {
    "order_id": "ORD1075",
    "customer_name": "Dale Schroeder",
    "region": "South America",
    "shipping_address": "394 Gonzalez Hill Apt. 521, North Joseph, LA 98948",
    "weight_kg": 0.64,
    "shipping_cost_usd": 7.19,
    "status": "Delivered",
    "order_date": "2025-10-01",
    "delivery_date": "2025-10-25"
  },
  {
    "order_id": "ORD1076",
    "customer_name": "Shawn Olson",
    "region": "South America",
    "shipping_address": "338 Johnson Roads Suite 264, Fordberg, OR 64719",
    "weight_kg": 1.72,
    "shipping_cost_usd": 19.11,
    "status": "Delivered",
    "order_date": "2025-09-26",
    "delivery_date": "2025-10-29"
  },
  {
    "order_id": "ORD1077",
    "customer_name": "Joshua Tate",
    "region": "Australia",
    "shipping_address": "8750 Lauren Harbors, Mckeeside, VT 02496",
    "weight_kg": 4.43,
    "shipping_cost_usd": 24.08,
    "status": "Pending",
    "order_date": "2025-10-01",
    "delivery_date": "2025-11-05"
  },
  {
    "order_id": "ORD1078",
    "customer_name": "Lee Drake",
    "region": "Asia",
    "shipping_address": "583 Mason Knolls, Erinport, OH 92103",
    "weight_kg": 4.23,
    "shipping_cost_usd": 9.49,
    "status": "Pending",
    "order_date": "2025-09-23",
    "delivery_date": "2025-10-30"
  },
  {
    "order_id": "ORD1079",
    "customer_name": "Scott Wright",
    "region": "Asia",
    "shipping_address": "466 Jose Common Suite 219, Port Adamborough, CO 02176",
    "weight_kg": 4.66,
    "shipping_cost_usd": 12.52,
    "status": "In Transit",
    "order_date": "2025-09-29",
    "delivery_date": "2025-11-02"
  },
  {
    "order_id": "ORD1080",
    "customer_name": "Felicia Carrillo",
    "region": "Europe",
    "shipping_address": "55823 Mallory Brook, Billyshire, VT 42538",
    "weight_kg": 4.91,
    "shipping_cost_usd": 16.88,
    "status": "In Transit",
    "order_date": "2025-10-19",
    "delivery_date": "2025-10-26"
  },
  {
    "order_id": "ORD1081",
    "customer_name": "Samantha Johnson",
    "region": "South America",
    "shipping_address": "28387 Mack Road, New Adamtown, PA 13968",
    "weight_kg": 0.82,
    "shipping_cost_usd": 9.2,
    "status": "Delivered",
    "order_date": "2025-10-20",
    "delivery_date": "2025-11-04"
  },
  {
    "order_id": "ORD1082",
    "customer_name": "Scott Roberts",
    "region": "South America",
    "shipping_address": "3111 Gray Forges Suite 002, Kaylaberg, MA 85062",
    "weight_kg": 2.63,
    "shipping_cost_usd": 24.83,
    "status": "In Transit",
    "order_date": "2025-09-27",
    "delivery_date": "2025-10-30"
  },
  {
    "order_id": "ORD1083",
    "customer_name": "Sandra Matthews",
    "region": "Middle East",
    "shipping_address": "PSC 0222, Box 3534, APO AA 96147",
    "weight_kg": 3.89,
    "shipping_cost_usd": 21.81,
    "status": "Pending",
    "order_date": "2025-10-15",
    "delivery_date": "2025-11-03"
  },
  {
    "order_id": "ORD1084",
    "customer_name": "Malik Nelson",
    "region": "South America",
    "shipping_address": "PSC 1002, Box 1617, APO AP 34895",
    "weight_kg": 3.02,
    "shipping_cost_usd": 21.95,
    "status": "Pending",
    "order_date": "2025-10-08",
    "delivery_date": "2025-11-03"
  },
  {
    "order_id": "ORD1085",
    "customer_name": "Carrie Murray",
    "region": "Middle East",
    "shipping_address": "9731 Kenneth Isle Apt. 060, Hansonborough, CT 27336",
    "weight_kg": 4.57,
    "shipping_cost_usd": 14.76,
    "status": "In Transit",
    "order_date": "2025-10-16",
    "delivery_date": "2025-10-29"
  },
  {
    "order_id": "ORD1086",
    "customer_name": "Douglas Turner",
    "region": "Asia",
    "shipping_address": "PSC 4103, Box 5825, APO AP 25220",
    "weight_kg": 2.93,
    "shipping_cost_usd": 17.94,
    "status": "In Transit",
    "order_date": "2025-10-14",
    "delivery_date": "2025-10-25"
  },
  {
    "order_id": "ORD1087",
    "customer_name": "Emily Schultz",
    "region": "South America",
    "shipping_address": "4878 Dalton Drive Apt. 493, North Antonio, VA 48258",
    "weight_kg": 1.16,
    "shipping_cost_usd": 5.01,
    "status": "Delivered",
    "order_date": "2025-10-05",
    "delivery_date": "2025-10-31"
  },
  {
    "order_id": "ORD1088",
    "customer_name": "Dr. Elizabeth Pearson DDS",
    "region": "Australia",
    "shipping_address": "PSC 9618, Box 3967, APO AE 97389",
    "weight_kg": 4.64,
    "shipping_cost_usd": 23.52,
    "status": "In Transit",
    "order_date": "2025-10-05",
    "delivery_date": "2025-11-05"
  },
  {
    "order_id": "ORD1089",
    "customer_name": "Kayla Taylor",
    "region": "Middle East",
    "shipping_address": "23620 Mary Islands Suite 608, Luisland, ID 61796",
    "weight_kg": 4.99,
    "shipping_cost_usd": 16.15,
    "status": "In Transit",
    "order_date": "2025-10-14",
    "delivery_date": "2025-10-30"
  },
  {
    "order_id": "ORD1090",
    "customer_name": "John Wilson",
    "region": "Asia",
    "shipping_address": "083 Wilson Port Suite 355, East Lindsayton, ME 89689",
    "weight_kg": 1.63,
    "shipping_cost_usd": 20.86,
    "status": "In Transit",
    "order_date": "2025-10-16",
    "delivery_date": "2025-10-23"
  },
  {
    "order_id": "ORD1091",
    "customer_name": "Devin Jackson",
    "region": "Asia",
    "shipping_address": "USNS Alvarado, FPO AA 10300",
    "weight_kg": 2.07,
    "shipping_cost_usd": 11.13,
    "status": "Pending",
    "order_date": "2025-10-07",
    "delivery_date": "2025-11-05"
  },
  {
    "order_id": "ORD1092",
    "customer_name": "Paul Ford",
    "region": "Australia",
    "shipping_address": "88866 Hannah Manors Apt. 836, Port Emilymouth, CT 87102",
    "weight_kg": 2.09,
    "shipping_cost_usd": 20.1,
    "status": "Delivered",
    "order_date": "2025-10-06",
    "delivery_date": "2025-10-29"
  },
  {
    "order_id": "ORD1093",
    "customer_name": "Lucas Martin",
    "region": "South America",
    "shipping_address": "53476 Johnson Dam Apt. 761, Thomasberg, PA 86278",
    "weight_kg": 2.35,
    "shipping_cost_usd": 10.19,
    "status": "In Transit",
    "order_date": "2025-10-02",
    "delivery_date": "2025-10-26"
  },
  {
    "order_id": "ORD1094",
    "customer_name": "Elizabeth Cole",
    "region": "Australia",
    "shipping_address": "241 Ryan Forges Apt. 188, South Lorraine, KS 73888",
    "weight_kg": 1.89,
    "shipping_cost_usd": 6.27,
    "status": "Pending",
    "order_date": "2025-10-04",
    "delivery_date": "2025-10-29"
  },
  {
    "order_id": "ORD1095",
    "customer_name": "Alec Pham",
    "region": "Middle East",
    "shipping_address": "620 Jerry Mills Apt. 397, Bridgesshire, IL 79052",
    "weight_kg": 3.77,
    "shipping_cost_usd": 13.09,
    "status": "Delivered",
    "order_date": "2025-09-26",
    "delivery_date": "2025-10-27"
  },
  {
    "order_id": "ORD1096",
    "customer_name": "Cody Buchanan",
    "region": "Australia",
    "shipping_address": "084 Meyer Brook, Duketown, GA 29346",
    "weight_kg": 2.08,
    "shipping_cost_usd": 11.25,
    "status": "In Transit",
    "order_date": "2025-09-28",
    "delivery_date": "2025-11-03"
  },
  {
    "order_id": "ORD1097",
    "customer_name": "Margaret Hernandez",
    "region": "Australia",
    "shipping_address": "0020 Heather Avenue Suite 877, North Kristinaborough, SC 27147",
    "weight_kg": 2.23,
    "shipping_cost_usd": 22.11,
    "status": "Delivered",
    "order_date": "2025-10-18",
    "delivery_date": "2025-10-26"
  },
  {
    "order_id": "ORD1098",
    "customer_name": "Michele Patel",
    "region": "Asia",
    "shipping_address": "83008 Elizabeth Dam Apt. 308, West Alicefurt, DE 23045",
    "weight_kg": 1.84,
    "shipping_cost_usd": 11.12,
    "status": "Delivered",
    "order_date": "2025-10-20",
    "delivery_date": "2025-11-04"
  },
  {
    "order_id": "ORD1099",
    "customer_name": "Patricia Hall",
    "region": "Australia",
    "shipping_address": "651 Riley Passage Apt. 170, New Wanda, DE 22317",
    "weight_kg": 4.92,
    "shipping_cost_usd": 18.56,
    "status": "Pending",
    "order_date": "2025-10-17",
    "delivery_date": "2025-10-23"
  },
  {
    "order_id": "ORD1100",
    "customer_name": "Curtis Patterson",
    "region": "North America",
    "shipping_address": "631 Tracy Islands, North Paula, RI 93411",
    "weight_kg": 4.88,
    "shipping_cost_usd": 15.51,
    "status": "Delivered",
    "order_date": "2025-09-28",
    "delivery_date": "2025-11-05"
  }
]
'''
nameregion={}
name1={}
for rec in shipping:
   # print(rec["order_id"],"--->",rec["customer_name"])
   nameregion[rec["order_id"]]=(rec["customer_name"],rec["region"])
print(nameregion)

for rec1 in shipping:
   name1[rec1["order_id"]]=(rec["customer_name"],rec["shipping_address"].split())'''
'''
ignore = ['Box', 'Unit']
pincode_data = {}
for rec in shipping:
    adds = rec['shipping_address'].split(',')
    pin = adds[-1].split(' ')[-1]
    place = adds[-2]
    place = place.strip()
    if not place.replace(' ', '').isalpha():
        place = place.split()[0]
        place = place if place not in ignore else 'Invalid'
    pincode_data[rec['order_id']] = (rec['customer_name'], place, pin)'''

orderid=input("enter the orderid : ")
for record in shipping:
    if str(record["order_id"])==orderid:
        print(record["customer_name"].split(' ')[0])
else:
  print("invalid ordered id")

udate=input(" enter date in the format of yyyy-mm-dd  :")
udate=datetime.strptime(udate,"%Y-%m-%d")
for daterec in shipping:
  order_date=datetime.strptime(daterec["order_date"],"%Y-%m-%d")
  if udate<order_date:
     print(daterec)
# Out:
# invalid ordered id
# {'order_id': 'ORD1040', 'customer_name': 'Joseph Porter', 'region': 'Asia', 'shipping_address': 'PSC 1199, Box 3895, APO AP 32779', 'weight_kg': 1.63, 'shipping_cost_usd': 6.45, 'status': 'Pending', 'order_date': '2025-09-22', 'delivery_date': '2025-11-03'}
# {'order_id': 'ORD1050', 'customer_name': 'Christopher Cisneros', 'region': 'North America', 'shipping_address': '89654 Nguyen Mall Suite 645, Christopherhaven, FL 23330', 'weight_kg': 0.92, 'shipping_cost_usd': 17.81, 'status': 'Pending', 'order_date': '2025-09-24', 'delivery_date': '2025-10-22'}
# {'order_id': 'ORD1065', 'customer_name': 'Steven Salazar', 'region': 'Australia', 'shipping_address': '152 Thomas Estates Apt. 882, Robersonstad, NE 47698', 'weight_kg': 3.33, 'shipping_cost_usd': 6.76, 'status': 'In Transit', 'order_date': '2025-09-22', 'delivery_date': '2025-10-26'}
# ...
