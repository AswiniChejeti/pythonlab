# %%
"""
we have two types of modules:
1, a simple python file
2, package

we can access four componwents from module :
1,variables
2,metods/functions
3,class(type)
4,modules

namespace:
set of all names (identifiers/symbols) in a specific scope

package:
a directory with namespace

from math import sqrt
math=module
sqrt=function/class

first write builtin modules
then give me single line /twice of empty lines gap
then mention coustom define modules


difference between folder and package:
a package have a facility to define a namespace



"""

# %%
#using a built-in module
import math

print(math.sqrt(16))                        # Output: 4.0
print(math.pi)                                 # Output: 3.141592653589793

# %%
# Using from ... import ...
from math import sqrt

print(sqrt(25))                                      # Output: 5.0

# %%
#Importing multiple things from a module
from math import sqrt, pow

print(sqrt(36))                                            # Output: 6.0
print(pow(2, 3))                                            # Output: 8.0
